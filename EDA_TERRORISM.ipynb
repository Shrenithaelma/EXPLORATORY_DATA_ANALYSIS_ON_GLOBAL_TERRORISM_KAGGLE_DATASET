# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/globalterrorismdb_0718dist.csv',encoding='ISO-8859-1')
# Out:
# <ipython-input-81-d459fdd2edb1>:1: DtypeWarning: Columns (4,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/content/globalterrorismdb_0718dist.csv',encoding='ISO-8859-1')

# %%
df
# Out:
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0      197000000001   1970       7     2        NaN         0        NaN
# 1      197000000002   1970       0     0        NaN         0        NaN
# 2      197001000001   1970       1     0        NaN         0        NaN
# 3      197001000002   1970       1     0        NaN         0        NaN
# 4      197001000003   1970       1     0        NaN         0        NaN
# ...             ...    ...     ...   ...        ...       ...        ...
# 96370  201005070019   2010       5     7        NaN         0        NaN
# 96371  201005070020   2010       5     7        NaN         0        NaN
# 96372  201005080001   2010       5     8        NaN         0        NaN
# 96373  201005080002   2010       5     8        NaN         0        NaN
# 96374  201005080003   2010       5     8        NaN         0        NaN
#
#        country         country_txt  region  ... addnotes  \
# 0           58  Dominican Republic       2  ...      NaN
# 1          130              Mexico       1  ...      NaN
# 2          160         Philippines       5  ...      NaN
# 3           78              Greece       8  ...      NaN
# 4          101               Japan       4  ...      NaN
# ...        ...                 ...     ...  ...      ...
# 96370      160         Philippines       5  ...      NaN
# 96371      205            Thailand       5  ...      NaN
# 96372      153            Pakistan       6  ...      NaN
# 96373      153            Pakistan       6  ...      NaN
# 96374      153            Pakistan       6  ...      NaN
#
#                                                   scite1  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 96370  National Counterterrorism Center, "One Soldier...
# 96371  Janes Intelligence, Militant Kills Police Of...
# 96372  National Counterterrorism Center, "One Railroa...
# 96373  National Counterterrorism Center, "Four Police...
# 96374                                                NaN
#
#                                                   scite2  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 96370  Xinhua News Agency, "Philippine Troops Securin...
# 96371  Zoe Daniel, Police Killed in Thai Unrest, Le...
# 96372  Nation, "Blast Damages Rail Track," LexisNexis...
# 96373  Right Vision News, "Pakistan: Three Personnel ...
# 96374                                                NaN
#
#                                                   scite3  dbsource  INT_LOG  \
# 0                                                    NaN      PGIS      0.0
# 1                                                    NaN      PGIS      0.0
# 2                                                    NaN      PGIS     -9.0
# 3                                                    NaN      PGIS     -9.0
# 4                                                    NaN      PGIS     -9.0
# ...                                                  ...       ...      ...
# 96370                                                NaN      ISVG      0.0
# 96371  BBC Monitoring Asia Pacific, Two Policemen Sa...      ISVG     -9.0
# 96372  Pakistan Newswire, "Railway Damaged in Explosi...      ISVG     -9.0
# 96373                                                NaN      ISVG     -9.0
# 96374                                                NaN       NaN      NaN
#
#        INT_IDEO INT_MISC INT_ANY  related
# 0           0.0      0.0     0.0      NaN
# 1           1.0      1.0     1.0      NaN
# 2          -9.0      1.0     1.0      NaN
# 3          -9.0      1.0     1.0      NaN
# 4          -9.0      1.0     1.0      NaN
# ...         ...      ...     ...      ...
# 96370       0.0      0.0     0.0      NaN
# 96371      -9.0      0.0    -9.0      NaN
# 96372      -9.0      0.0    -9.0      NaN
# 96373      -9.0      0.0    -9.0      NaN
# 96374       NaN      NaN     NaN      NaN
#
# [96375 rows x 135 columns]

# %%
print("There are {} rows and {} columns in the dataset".format(df.shape[0],df.shape[1]))
# Out:
# There are 96375 rows and 135 columns in the dataset

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0      0.0       0.0      0.0     0.0      NaN
# 1      0.0       1.0      1.0     1.0      NaN
# 2     -9.0      -9.0      1.0     1.0      NaN
# 3     -9.0      -9.0      1.0     1.0      NaN
# 4     -9.0      -9.0      1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %%
df.tail()
# Out:
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 96370  201005070019   2010       5     7        NaN         0        NaN
# 96371  201005070020   2010       5     7        NaN         0        NaN
# 96372  201005080001   2010       5     8        NaN         0        NaN
# 96373  201005080002   2010       5     8        NaN         0        NaN
# 96374  201005080003   2010       5     8        NaN         0        NaN
#
#        country  country_txt  region  ... addnotes  \
# 96370      160  Philippines       5  ...      NaN
# 96371      205     Thailand       5  ...      NaN
# 96372      153     Pakistan       6  ...      NaN
# 96373      153     Pakistan       6  ...      NaN
# 96374      153     Pakistan       6  ...      NaN
#
#                                                   scite1  \
# 96370  National Counterterrorism Center, "One Soldier...
# 96371  Janes Intelligence, Militant Kills Police Of...
# 96372  National Counterterrorism Center, "One Railroa...
# 96373  National Counterterrorism Center, "Four Police...
# 96374                                                NaN
#
#                                                   scite2  \
# 96370  Xinhua News Agency, "Philippine Troops Securin...
# 96371  Zoe Daniel, Police Killed in Thai Unrest, Le...
# 96372  Nation, "Blast Damages Rail Track," LexisNexis...
# 96373  Right Vision News, "Pakistan: Three Personnel ...
# 96374                                                NaN
#
#                                                   scite3  dbsource  INT_LOG  \
# 96370                                                NaN      ISVG      0.0
# 96371  BBC Monitoring Asia Pacific, Two Policemen Sa...      ISVG     -9.0
# 96372  Pakistan Newswire, "Railway Damaged in Explosi...      ISVG     -9.0
# 96373                                                NaN      ISVG     -9.0
# 96374                                                NaN       NaN      NaN
#
#        INT_IDEO INT_MISC INT_ANY  related
# 96370       0.0      0.0     0.0      NaN
# 96371      -9.0      0.0    -9.0      NaN
# 96372      -9.0      0.0    -9.0      NaN
# 96373      -9.0      0.0    -9.0      NaN
# 96374       NaN      NaN     NaN      NaN
#
# [5 rows x 135 columns]

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.dtypes
# Out:
# eventid         int64
# iyear           int64
# imonth          int64
# iday            int64
# approxdate     object
#                ...
# INT_LOG       float64
# INT_IDEO      float64
# INT_MISC      float64
# INT_ANY       float64
# related        object
# Length: 135, dtype: object

# %%
df.describe()
# Out:
#             eventid         iyear        imonth          iday      extended  \
# count  9.637500e+04  96375.000000  96375.000000  96375.000000  96375.000000
# mean   1.992469e+11   1992.402957      6.406298     15.316337      0.031087
# std    1.025172e+09     10.252282      3.389023      8.825243      0.173553
# min    1.970000e+11   1970.000000      0.000000      0.000000      0.000000
# 25%    1.985010e+11   1985.000000      3.000000      8.000000      0.000000
# 50%    1.991092e+11   1991.000000      6.000000     15.000000      0.000000
# 75%    2.001052e+11   2001.000000      9.000000     23.000000      0.000000
# max    2.010051e+11   2010.000000     12.000000     31.000000      1.000000
#
#             country        region      latitude     longitude   specificity  \
# count  96375.000000  96375.000000  92333.000000  9.233200e+04  96372.000000
# mean     139.563901      6.265971     20.840253 -9.278742e+02      1.436008
# std      127.371907      3.120878     22.164515  2.836352e+05      1.067938
# min        4.000000      1.000000    -53.154613 -8.618590e+07      1.000000
# 25%       61.000000      3.000000      6.952840 -7.325084e+01      1.000000
# 50%       98.000000      6.000000     26.401436  1.435548e+01      1.000000
# 75%      167.000000     10.000000     36.705776  4.864342e+01      1.000000
# max     1003.000000     12.000000     74.633553  1.793667e+02      5.000000
#
#        ...     ransomamt   ransomamtus    ransompaid  ransompaidus  \
# count  ...  9.260000e+02  1.580000e+02  3.600000e+02    150.000000
# mean   ...  3.188212e+06  5.315108e+05  6.951182e+05    822.546667
# std    ...  3.430720e+07  2.287766e+06  3.352258e+06   5553.943861
# min    ... -9.900000e+01 -9.900000e+01 -9.900000e+01    -99.000000
# 25%    ...  0.000000e+00  0.000000e+00 -9.900000e+01      0.000000
# 50%    ...  1.100000e+04  0.000000e+00  0.000000e+00      0.000000
# 75%    ...  5.000000e+05  0.000000e+00  5.000000e+04      0.000000
# max    ...  1.000000e+09  2.000000e+07  4.100000e+07  48000.000000
#
#        hostkidoutcome    nreleased       INT_LOG      INT_IDEO      INT_MISC  \
# count     4121.000000  3537.000000  96374.000000  96374.000000  96374.000000
# mean         4.351371   -18.398077     -4.179499     -4.138295      0.113744
# std          2.071490    63.414226      4.544628      4.599382      0.729559
# min          1.000000   -99.000000     -9.000000     -9.000000     -9.000000
# 25%          2.000000   -99.000000     -9.000000     -9.000000      0.000000
# 50%          4.000000     1.000000      0.000000      0.000000      0.000000
# 75%          7.000000     2.000000      0.000000      0.000000      0.000000
# max          7.000000  1201.000000      1.000000      1.000000      1.000000
#
#             INT_ANY
# count  96374.000000
# mean      -3.440440
# std        4.622743
# min       -9.000000
# 25%       -9.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 77 columns]

# %%
for n in df.columns:
  print(n)
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# weaptype1_txt
# weapsubtype1
# weapsubtype1_txt
# weaptype2
# weaptype2_txt
# weapsubtype2
# weapsubtype2_txt
# weaptype3
# weaptype3_txt
# weapsubtype3
# weapsubtype3_txt
# weaptype4
# weaptype4_txt
# weapsubtype4
# weapsubtype4_txt
# weapdetail
# nkill
# nkillus
# nkillter
# nwound
# nwoundus
# nwoundte
# property
# propextent
# propextent_txt
# propvalue
# propcomment
# ishostkid
# nhostkid
# nhostkidus
# nhours
# ndays
# divert
# kidhijcountry
# ransom
# ransomamt
# ransomamtus
# ransompaid
# ransompaidus
# ransomnote
# hostkidoutcome
# hostkidoutcome_txt
# nreleased
# addnotes
# scite1
# scite2
# scite3
# dbsource
# INT_LOG
# INT_IDEO
# INT_MISC
# INT_ANY
# related

# %%
df.isnull().sum()
# Out:
# eventid           0
# iyear             0
# imonth            0
# iday              0
# approxdate    96074
#               ...
# INT_LOG           1
# INT_IDEO          1
# INT_MISC          1
# INT_ANY           1
# related       86041
# Length: 135, dtype: int64

# %%
import missingno as ms
ms.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# The discontinuous shaded are represents the presence of missing values

# %% [markdown]
# ## **DATA CLEANING**

# %%
df=df[['iyear','country_txt','region_txt','city','attacktype1_txt','targtype1_txt','gname','nkill','longitude']]
df.head()
# Out:
#    iyear         country_txt                   region_txt           city  \
# 0   1970  Dominican Republic  Central America & Caribbean  Santo Domingo
# 1   1970              Mexico                North America    Mexico city
# 2   1970         Philippines               Southeast Asia        Unknown
# 3   1970              Greece               Western Europe         Athens
# 4   1970               Japan                    East Asia        Fukouka
#
#                   attacktype1_txt                targtype1_txt  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                 gname  nkill   longitude
# 0                              MANO-D    1.0  -69.951164
# 1  23rd of September Communist League    0.0  -99.086624
# 2                             Unknown    1.0  120.599741
# 3                             Unknown    NaN   23.762728
# 4                             Unknown    NaN  130.396361

# %%
# change the name of the columns.
df.rename(columns = {'iyear':'year', 'country_txt':'country','region_txt':'region','attacktype1_txt':'attacktype','targty_txt':'target','gname':'group','nkill':'kill','longitude':'longitude'},inplace=True)
# Out:
# <ipython-input-93-b4b662c41e70>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {'iyear':'year', 'country_txt':'country','region_txt':'region','attacktype1_txt':'attacktype','targty_txt':'target','gname':'group','nkill':'kill','longitude':'longitude'},inplace=True)

# %%
ms.matrix(df)
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# year                0
# country             0
# region              0
# city              350
# attacktype          0
# targtype1_txt       0
# group               0
# kill             6503
# longitude        4043
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96375 entries, 0 to 96374
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           96375 non-null  int64
#  1   country        96375 non-null  object
#  2   region         96375 non-null  object
#  3   city           96025 non-null  object
#  4   attacktype     96375 non-null  object
#  5   targtype1_txt  96375 non-null  object
#  6   group          96375 non-null  object
#  7   kill           89872 non-null  float64
#  8   longitude      92332 non-null  float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 6.6+ MB

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# year             0
# country          0
# region           0
# city             0
# attacktype       0
# targtype1_txt    0
# group            0
# kill             0
# longitude        0
# dtype: int64

# %%
# change datatype of killed column from float to int.
df=df.astype({'kill':'int'})

# %%
print("Country with the most attacks:",df['country'].value_counts().idxmax())
print("City with the most attacks:",df['city'].value_counts().index[1]) #as first entry is 'unknown'
print("Region with the most attacks:",df['region'].value_counts().idxmax())
print("Year with the most attacks:",df['year'].value_counts().idxmax())
print("Targettype with the most attacks:",df['targtype1_txt'].value_counts().idxmax())
print("Group with the most attacks:",df['group'].value_counts().index[1])
print("Most Attack Types:",df['attacktype'].value_counts().idxmax())
# Out:
# Country with the most attacks: Colombia
# City with the most attacks: Baghdad
# Region with the most attacks: Middle East & North Africa
# Year with the most attacks: 1992
# Targettype with the most attacks: Private Citizens & Property
# Group with the most attacks: Shining Path (SL)
# Most Attack Types: Bombing/Explosion

# %%
df['year'].value_counts(dropna = False).sort_index()
# Out:
# 1970     602
# 1971     401
# 1972     508
# 1973     418
# 1974     521
# 1975     579
# 1976     799
# 1977    1167
# 1978    1313
# 1979    2152
# 1980    2130
# 1981    1845
# 1982    1653
# 1983    1864
# 1984    2548
# 1985    2312
# 1986    2350
# 1987    2906
# 1988    3441
# 1989    4113
# 1990    3642
# 1991    4304
# 1992    4809
# 1994    3211
# 1995    2915
# 1996    2854
# 1997    2931
# 1998     847
# 1999    1293
# 2000    1715
# 2001    1863
# 2002    1300
# 2003    1243
# 2004    1123
# 2005    1969
# 2006    2580
# 2007    3123
# 2008    4609
# 2009    4539
# 2010    1470
# Name: year, dtype: int64

# %% [markdown]
# ## Number of Terrorist Activities each Year
#
# ---
#
#
#
# ---

# %%
import seaborn as sns
x_year = df['year'].unique()
y_count_years = df['year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = x_year,
           y = y_count_years,
           palette = 'rocket')
plt.xticks(rotation = 45)
plt.xlabel('Attack Year')
plt.ylabel('Number of Attacks each year')
plt.title('Attack_of_Years')
plt.show()

# %% [markdown]
# # Terrorist Activities by Region in each Year through Area Plot

# %%
pd.crosstab(df.year,df.region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Year')
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.show()

# %%
df_region=df.region.value_counts().to_frame().reset_index()
df_region.columns=['region_name','count']

# %%
# total number of terrorist attacks in various regions of the world.
sns.barplot(y='region_name',x='count',data=df_region,orient='h',palette='flare',ec='black')
plt.grid(True)
plt.title("Number of Total Attacks in Each Region")
plt.ylabel('Region')
plt.xlabel('Number of attacks')
plt.show()

# %% [markdown]
# ## Top 10 countries with most attacks

# %%
top_10_country=df.country.value_counts()[:10].to_frame().reset_index()
top_10_country.columns=['country_name','count']

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=top_10_country,x='country_name',y='count',ec='black',lw=1)
plt.grid(True)
plt.title('Top 10 Countries with most Attacks',fontsize=20)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.show()

# %% [markdown]
# ## Target Methods by Terrorists

# %%
target_type=df.attacktype.value_counts()[0:10].to_frame().reset_index()
target_type.columns=['target_type','count']

# %%
plt.figure(figsize=(25,10))
sns.barplot(x='target_type',y='count',data=target_type,palette='coolwarm',ec='black')
plt.xlabel('Target Type',fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.title("Target Method by Terrorists",fontsize=30)
plt.grid(True)

# %% [markdown]
# ## City where terrorist killed most number of people in the world ?

# %%
top10_city=df.city.value_counts().to_frame()[0:10].reset_index()
top10_city.columns=['city','count']

# %%
plt.figure(figsize=(12,5))
sns.barplot(x='city',y='count',data=top10_city,ec='black',palette='Set3')
plt.title("Most affected City in the World",fontsize=15)
plt.xlabel('Name of the City',fontsize=12)
plt.ylabel("Number of the Attacks",fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Deadliest year in terms of death of people by terrorism

# %%
year=(df.groupby(['year'])['kill'].size()).reset_index()
# sort the year dataset in descending order of the killed colum.
year=year.sort_values(by=['kill'],ascending=False).head()
year
# Out:
#     year  kill
# 22  1992  4809
# 37  2008  4609
# 38  2009  4539
# 21  1991  4304
# 19  1989  4113

# %%
# bar-plot for top 5 years where maximum number of people killed by terrorism.
plt.figure(figsize=(10,5))
color=['red','orange','pink','blue','yellow']
plt.bar(list(year['year']),list(year['kill']),color=color,ec='black')
plt.grid(True)
plt.xlabel('Name of the Year')
plt.ylabel('Number of People Killed')
plt.show()

# %%
killData = df.loc[:,'kill']
print('Number of people killed by terror attack:', int(sum(killData.dropna())))
attackData = df.loc[:,'attacktype']
# attackData
typeKillData = pd.concat([attackData, killData], axis=1)
typeKillFormatData = typeKillData.pivot_table(columns='attacktype', values='kill', aggfunc='sum')
typeKillFormatData
# Out:
# Number of people killed by terror attack: 199453
# attacktype  Armed Assault  Assassination  Bombing/Explosion  \
# kill                90490          17772              66788
#
# attacktype  Facility/Infrastructure Attack  Hijacking  \
# kill                                  2473       3544
#
# attacktype  Hostage Taking (Barricade Incident)  Hostage Taking (Kidnapping)  \
# kill                                       1637                         3978
#
# attacktype  Unarmed Assault  Unknown
# kill                    617    12154

# %%
#Number of Killed in Terrorist Attacks by Countries
countryData = df.loc[:,'country']
# countyData
countryKillData = pd.concat([countryData, killData], axis=1)
countryKillFormatData = countryKillData.pivot_table(columns='country', values='kill', aggfunc='sum')
countryKillFormatData
# Out:
# country  Afghanistan  Albania  Algeria  Angola  Argentina  Armenia  Australia  \
# kill            5721       41     9717    2574        487       31         13
#
# country  Austria  Azerbaijan  Bahamas  ...  Vietnam  Wallis and Futuna  \
# kill          28         188        1  ...        1                  0
#
# country  West Bank and Gaza Strip  West Germany (FRG)  Western Sahara  Yemen  \
# kill                         1131                  97               0    322
#
# country  Yugoslavia  Zaire  Zambia  Zimbabwe
# kill            119    154      49       149
#
# [1 rows x 201 columns]

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=25
fig_size[1]=25
plt.rcParams["figure.figsize"] = fig_size

# %%
labels = countryKillFormatData.columns.tolist()
labels = labels[152:206]
index = np.arange(len(labels))
transpoze = countryKillFormatData.T
values = transpoze.values.tolist()
values = values[152:206]
values = [int(i[0]) for i in values]
colors = ['red', 'green', 'blue', 'purple', 'yellow', 'brown', 'black', 'gray', 'magenta', 'orange']
fig, ax = plt.subplots(1, 1)
ax.yaxis.grid(True)
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=25
fig_size[1]=25
plt.rcParams["figure.figsize"] = fig_size
plt.bar(index, values, color = colors, width = 0.9)
plt.ylabel('Killed People', fontsize=20)
plt.xlabel('Countries', fontsize = 20)
plt.xticks(index, labels, fontsize=18, rotation=90)
plt.title('Number of people killed by countries', fontsize = 20)
plt.show()
